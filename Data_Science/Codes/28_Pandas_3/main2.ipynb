# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# df.drop('PassengerId')
# As by default axis = 0, drop is searching the axis = 0 (means x-axis or the rows) to delete.

# %%
df.drop('PassengerId', axis = 1)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop('PassengerId', axis = 1, inplace = True)
# We can also reassign the dataframe.

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
df.drop(3)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
df.drop(3, inplace = True)

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 4         0       3                           Allen, Mr. William Henry
# 5         0       3                                   Moran, Mr. James
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
# 5    male   NaN      0      0            330877   8.4583   NaN        Q

# %%
df.set_index('Name', inplace = True)

# %%
df.head()
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
#
#                                                      Age  SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                             22.0      1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0      1      0
# Heikkinen, Miss. Laina                              26.0      0      0
# Allen, Mr. William Henry                            35.0      0      0
# Moran, Mr. James                                     NaN      0      0
#
# ...

# %%
df.reset_index(inplace = True)

# %%
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    male  35.0      0      0            373450   8.0500   NaN        S
# 4    male   NaN      0      0            330877   8.4583   NaN        Q

# %%
data = {
    "key1" : [1, 2, 3, 4],
    "key2" : [5, 6, 7, 8],
    "key3" : [9, 10, 11, 12]
}

# %%
pd.DataFrame(data)
# Out:
#    key1  key2  key3
# 0     1     5     9
# 1     2     6    10
# 2     3     7    11
# 3     4     8    12

# %%
df = pd.read_csv("../static/28_Pandas_3/taxonomy.csv")

# %%
df.head()
# Out:
#   taxonomy_id                     name parent_id     parent_name
# 0         101                Emergency       NaN             NaN
# 1      101-01        Disaster Response       101       Emergency
# 2      101-02           Emergency Cash       101       Emergency
# 3   101-02-01        Help Pay for Food    101-02  Emergency Cash
# 4   101-02-02  Help Pay for Healthcare    101-02  Emergency Cash

# %%
df.columns
# Out:
# Index(['taxonomy_id', 'name', 'parent_id', 'parent_name'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   taxonomy_id  290 non-null    object
#  1   name         290 non-null    object
#  2   parent_id    279 non-null    object
#  3   parent_name  279 non-null    object
# dtypes: object(4)
# memory usage: 9.2+ KB

# %%
df.dropna(inplace = True) # default axis = 0

# %%
df
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df = pd.read_csv("../static/28_Pandas_3/taxonomy.csv")

# %%
df
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df.dropna(axis = 1, inplace = True)

# %%
df
# Out:
#     taxonomy_id                          name
# 0           101                     Emergency
# 1        101-01             Disaster Response
# 2        101-02                Emergency Cash
# 3     101-02-01             Help Pay for Food
# 4     101-02-02       Help Pay for Healthcare
# ..          ...                           ...
# 285   111-01-07              Workplace Rights
# 286      111-02                     Mediation
# 287      111-03                        Notary
# 288      111-04                Representation
# 289      111-05  Translation & Interpretation
#
# [290 rows x 2 columns]

# %%
df = pd.read_csv("../static/28_Pandas_3/taxonomy.csv")

# %%
df
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df.fillna("HELLO", inplace = True)

# %%
df
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency     HELLO                 HELLO
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop("PassengerId", axis = 1, inplace = True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
dfGroupBySurvived = df.groupby("Survived")

# %%
dfGroupBySurvived

# %%
dfGroupBySurvived.sum()
# Out:
# C:\Users\SOUMYA~1\AppData\Local\Temp/ipykernel_8608/3790316486.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dfGroupBySurvived.sum()
#           Pclass       Age  SibSp  Parch        Fare
# Survived
# 0           1390  12985.50    304    181  12142.7199
# 1            667   8219.67    162    159  16551.2294

# %%
dfGroupBySurvived.mean()
# Out:
# C:\Users\SOUMYA~1\AppData\Local\Temp/ipykernel_8608/1790312150.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dfGroupBySurvived.mean()
#             Pclass        Age     SibSp     Parch       Fare
# Survived
# 0         2.531876  30.626179  0.553734  0.329690  22.117887
# 1         1.950292  28.343690  0.473684  0.464912  48.395408

# %%
dfGroupByPclass = df.groupby("Pclass")

# %%
dfGroupByPclass.mean()
# Out:
# C:\Users\SOUMYA~1\AppData\Local\Temp/ipykernel_8608/2019454948.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dfGroupByPclass.mean()
#         Survived        Age     SibSp     Parch       Fare
# Pclass
# 1       0.629630  38.233441  0.416667  0.356481  84.154687
# 2       0.472826  29.877630  0.402174  0.380435  20.662183
# 3       0.242363  25.140620  0.615071  0.393075  13.675550

# %%
dfGroupByPclass.sum()
# Out:
# C:\Users\SOUMYA~1\AppData\Local\Temp/ipykernel_8608/3097888861.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dfGroupByPclass.sum()
#         Survived      Age  SibSp  Parch        Fare
# Pclass
# 1            136  7111.42     90     77  18177.4125
# 2             87  5168.83     74     70   3801.8417
# 3            119  8924.92    302    193   6714.6951

# %%
dfGroupByPclass.max()
# Out:
# C:\Users\SOUMYA~1\AppData\Local\Temp/ipykernel_8608/3685516453.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   dfGroupByPclass.max()
#         Survived                         Name   Sex   Age  SibSp  Parch  \
# Pclass
# 1              1     Young, Miss. Marie Grice  male  80.0      3      4
# 2              1    del Carlo, Mr. Sebastiano  male  70.0      3      3
# 3              1  van Melkebeke, Mr. Philemon  male  74.0      8      6
#
#             Ticket      Fare
# Pclass
# 1        WE/P 5735  512.3292
# 2        W/C 14208   73.5000
# 3       W./C. 6609   69.5500

# %%
dfGroupByPclass.mean()
# Out:
# C:\Users\SOUMYA~1\AppData\Local\Temp/ipykernel_8608/2019454948.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dfGroupByPclass.mean()
#         Survived        Age     SibSp     Parch       Fare
# Pclass
# 1       0.629630  38.233441  0.416667  0.356481  84.154687
# 2       0.472826  29.877630  0.402174  0.380435  20.662183
# 3       0.242363  25.140620  0.615071  0.393075  13.675550

# %%
dfGroupByPclass.mean().T
# Out:
# C:\Users\SOUMYA~1\AppData\Local\Temp/ipykernel_8608/1688235409.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dfGroupByPclass.mean().T
# Pclass            1          2          3
# Survived   0.629630   0.472826   0.242363
# Age       38.233441  29.877630  25.140620
# SibSp      0.416667   0.402174   0.615071
# Parch      0.356481   0.380435   0.393075
# Fare      84.154687  20.662183  13.675550

# %%
dfGroupByPclass.mean().transpose()
# Out:
# C:\Users\SOUMYA~1\AppData\Local\Temp/ipykernel_8608/1013603732.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dfGroupByPclass.mean().transpose()
# Pclass            1          2          3
# Survived   0.629630   0.472826   0.242363
# Age       38.233441  29.877630  25.140620
# SibSp      0.416667   0.402174   0.615071
# Parch      0.356481   0.380435   0.393075
# Fare      84.154687  20.662183  13.675550

# %%
dfSubSet1 = df[["Name", "Pclass", "Survived"]][0: 5]
dfSubSet2 = df[["Name", "Pclass", "Survived"]][5: 10]

# %%
dfSubSet1
# Out:
#                                                 Name  Pclass  Survived
# 0                            Braund, Mr. Owen Harris       3         0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...       1         1
# 2                             Heikkinen, Miss. Laina       3         1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1         1
# 4                           Allen, Mr. William Henry       3         0

# %%
dfSubSet2
# Out:
#                                                 Name  Pclass  Survived
# 5                                   Moran, Mr. James       3         0
# 6                            McCarthy, Mr. Timothy J       1         0
# 7                     Palsson, Master. Gosta Leonard       3         0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3         1
# 9                Nasser, Mrs. Nicholas (Adele Achem)       2         1

# %%
pd.concat([dfSubSet1, dfSubSet2])
# Out:
#                                                 Name  Pclass  Survived
# 0                            Braund, Mr. Owen Harris       3         0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...       1         1
# 2                             Heikkinen, Miss. Laina       3         1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1         1
# 4                           Allen, Mr. William Henry       3         0
# 5                                   Moran, Mr. James       3         0
# 6                            McCarthy, Mr. Timothy J       1         0
# 7                     Palsson, Master. Gosta Leonard       3         0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3         1
# 9                Nasser, Mrs. Nicholas (Adele Achem)       2         1

# %%
dfSubSet1
# Out:
#                                                 Name  Pclass  Survived
# 0                            Braund, Mr. Owen Harris       3         0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...       1         1
# 2                             Heikkinen, Miss. Laina       3         1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1         1
# 4                           Allen, Mr. William Henry       3         0

# %%
dfSubSet2
# Out:
#                                                 Name  Pclass  Survived
# 5                                   Moran, Mr. James       3         0
# 6                            McCarthy, Mr. Timothy J       1         0
# 7                     Palsson, Master. Gosta Leonard       3         0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3         1
# 9                Nasser, Mrs. Nicholas (Adele Achem)       2         1

# %%
pd.concat([dfSubSet1, dfSubSet2], axis = 1)
# Out:
#                                                 Name  Pclass  Survived  \
# 0                            Braund, Mr. Owen Harris     3.0       0.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...     1.0       1.0
# 2                             Heikkinen, Miss. Laina     3.0       1.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)     1.0       1.0
# 4                           Allen, Mr. William Henry     3.0       0.0
# 5                                                NaN     NaN       NaN
# 6                                                NaN     NaN       NaN
# 7                                                NaN     NaN       NaN
# 8                                                NaN     NaN       NaN
# 9                                                NaN     NaN       NaN
#
#                                                 Name  Pclass  Survived
# 0                                                NaN     NaN       NaN
# ...

# %%
pd.concat([dfSubSet1, dfSubSet2], axis = 1).fillna("HELLO")
# Out:
#                                                 Name Pclass Survived  \
# 0                            Braund, Mr. Owen Harris    3.0      0.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1.0      1.0
# 2                             Heikkinen, Miss. Laina    3.0      1.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1.0      1.0
# 4                           Allen, Mr. William Henry    3.0      0.0
# 5                                              HELLO  HELLO    HELLO
# 6                                              HELLO  HELLO    HELLO
# 7                                              HELLO  HELLO    HELLO
# 8                                              HELLO  HELLO    HELLO
# 9                                              HELLO  HELLO    HELLO
#
#                                                 Name Pclass Survived
# 0                                              HELLO  HELLO    HELLO
# 1                                              HELLO  HELLO    HELLO
# ...

# %%
data1 = pd.DataFrame(data)
data1
# Out:
#    key1  key2  key3
# 0     1     5     9
# 1     2     6    10
# 2     3     7    11
# 3     4     8    12

# %%
data2 = pd.DataFrame({
    "key1" : [3, 2, 6, 1],
    "key2" : [7, 6, 81, 8],
    "key5" : [9, 10, 111, 12]
})

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     5     9
# 1     2     6    10
# 2     3     7    11
# 3     4     8    12

# %%
data2
# Out:
#    key1  key2  key5
# 0     3     7     9
# 1     2     6    10
# 2     6    81   111
# 3     1     8    12

# %%
pd.merge(data1, data2) # by default inner join(intersection)
# Out:
#    key1  key2  key3  key5
# 0     2     6    10    10
# 1     3     7    11     9

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     5     9
# 1     2     6    10
# 2     3     7    11
# 3     4     8    12

# %%
data2
# Out:
#    key1  key2  key5
# 0     3     7     9
# 1     2     6    10
# 2     6    81   111
# 3     1     8    12

# %%
pd.merge(data1, data2, how = "left") # left join(all the data of left table is present)
# Out:
#    key1  key2  key3  key5
# 0     1     5     9   NaN
# 1     2     6    10  10.0
# 2     3     7    11   9.0
# 3     4     8    12   NaN

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     5     9
# 1     2     6    10
# 2     3     7    11
# 3     4     8    12

# %%
data2
# Out:
#    key1  key2  key5
# 0     3     7     9
# 1     2     6    10
# 2     6    81   111
# 3     1     8    12

# %%
pd.merge(data1, data2, how = "right") # right join(all the data of right table is present)
# Out:
#    key1  key2  key3  key5
# 0     3     7  11.0     9
# 1     2     6  10.0    10
# 2     6    81   NaN   111
# 3     1     8   NaN    12

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     5     9
# 1     2     6    10
# 2     3     7    11
# 3     4     8    12

# %%
data2
# Out:
#    key1  key2  key5
# 0     3     7     9
# 1     2     6    10
# 2     6    81   111
# 3     1     8    12

# %%
pd.merge(data1, data2, how = 'outer') # outer join(all the data from both the tables are present)
# Out:
#    key1  key2  key3   key5
# 0     1     5   9.0    NaN
# 1     2     6  10.0   10.0
# 2     3     7  11.0    9.0
# 3     4     8  12.0    NaN
# 4     6    81   NaN  111.0
# 5     1     8   NaN   12.0

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     5     9
# 1     2     6    10
# 2     3     7    11
# 3     4     8    12

# %%
data2
# Out:
#    key1  key2  key5
# 0     3     7     9
# 1     2     6    10
# 2     6    81   111
# 3     1     8    12

# %%
pd.merge(data1, data2, how = "cross")
# Out:
#     key1_x  key2_x  key3  key1_y  key2_y  key5
# 0        1       5     9       3       7     9
# 1        1       5     9       2       6    10
# 2        1       5     9       6      81   111
# 3        1       5     9       1       8    12
# 4        2       6    10       3       7     9
# 5        2       6    10       2       6    10
# 6        2       6    10       6      81   111
# 7        2       6    10       1       8    12
# 8        3       7    11       3       7     9
# 9        3       7    11       2       6    10
# 10       3       7    11       6      81   111
# 11       3       7    11       1       8    12
# 12       4       8    12       3       7     9
# 13       4       8    12       2       6    10
# 14       4       8    12       6      81   111
# 15       4       8    12       1       8    12

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     5     9
# 1     2     6    10
# 2     3     7    11
# 3     4     8    12

# %%
data2
# Out:
#    key1  key2  key5
# 0     3     7     9
# 1     2     6    10
# 2     6    81   111
# 3     1     8    12

# %%
pd.merge(data1, data2, how = "left", left_on = "key2", right_on = "key1")
# Out:
#    key1_x  key2_x  key3  key1_y  key2_y   key5
# 0       1       5     9     NaN     NaN    NaN
# 1       2       6    10     6.0    81.0  111.0
# 2       3       7    11     NaN     NaN    NaN
# 3       4       8    12     NaN     NaN    NaN

# %%
pd.merge(data1, data2, how = "outer", on = "key1")
# Out:
#    key1  key2_x  key3  key2_y   key5
# 0     1     5.0   9.0     8.0   12.0
# 1     2     6.0  10.0     6.0   10.0
# 2     3     7.0  11.0     7.0    9.0
# 3     4     8.0  12.0     NaN    NaN
# 4     6     NaN   NaN    81.0  111.0

# %%
data3 = pd.DataFrame(
    {
        "key1" : [1, 2, 3, 4],
        "key2" : [5, 6, 7, 8],
        "key3" : [9, 10, 11, 12]
    },
    index = ['A', 'B', 'C', 'D']
)

# %%
data3
# Out:
#    key1  key2  key3
# A     1     5     9
# B     2     6    10
# C     3     7    11
# D     4     8    12

# %%
data4 = pd.DataFrame(
    {
        "key1" : [4, 2, 34, 4],
        "key2" : [5, 6, 72, 8],
        "key5" : [91, 10, 11, 12]
    },
    index = ['A', 'B', 'E', 'F']
)

# %%
data4
# Out:
#    key1  key2  key5
# A     4     5    91
# B     2     6    10
# E    34    72    11
# F     4     8    12

# %%
# data3.join(data4)
# columns names can't overlap

# %%
data4 = pd.DataFrame(
    {
        "key4" : [4, 2, 34, 4],
        "key5" : [5, 6, 72, 8],
        "key6" : [91, 10, 11, 12]
    },
    index = ['A', 'B', 'E', 'F']
)

# %%
data4
# Out:
#    key4  key5  key6
# A     4     5    91
# B     2     6    10
# E    34    72    11
# F     4     8    12

# %%
data3.join(data4) # by default left join
# merge works on values
# And join works on indices
# Out:
#    key1  key2  key3  key4  key5  key6
# A     1     5     9   4.0   5.0  91.0
# B     2     6    10   2.0   6.0  10.0
# C     3     7    11   NaN   NaN   NaN
# D     4     8    12   NaN   NaN   NaN

# %%
data3
# Out:
#    key1  key2  key3
# A     1     5     9
# B     2     6    10
# C     3     7    11
# D     4     8    12

# %%
data4
# Out:
#    key4  key5  key6
# A     4     5    91
# B     2     6    10
# E    34    72    11
# F     4     8    12

# %%
data3.join(data4, how = "right")
# Out:
#    key1  key2  key3  key4  key5  key6
# A   1.0   5.0   9.0     4     5    91
# B   2.0   6.0  10.0     2     6    10
# E   NaN   NaN   NaN    34    72    11
# F   NaN   NaN   NaN     4     8    12

# %%
data3.join(data4, how = "inner")
# Out:
#    key1  key2  key3  key4  key5  key6
# A     1     5     9     4     5    91
# B     2     6    10     2     6    10

# %%
data3.join(data4, how = "outer")
# Out:
#    key1  key2  key3  key4  key5  key6
# A   1.0   5.0   9.0   4.0   5.0  91.0
# B   2.0   6.0  10.0   2.0   6.0  10.0
# C   3.0   7.0  11.0   NaN   NaN   NaN
# D   4.0   8.0  12.0   NaN   NaN   NaN
# E   NaN   NaN   NaN  34.0  72.0  11.0
# F   NaN   NaN   NaN   4.0   8.0  12.0

# %%
data3.join(data4, how = "cross")
# Out:
#     key1  key2  key3  key4  key5  key6
# 0      1     5     9     4     5    91
# 1      1     5     9     2     6    10
# 2      1     5     9    34    72    11
# 3      1     5     9     4     8    12
# 4      2     6    10     4     5    91
# 5      2     6    10     2     6    10
# 6      2     6    10    34    72    11
# 7      2     6    10     4     8    12
# 8      3     7    11     4     5    91
# 9      3     7    11     2     6    10
# 10     3     7    11    34    72    11
# 11     3     7    11     4     8    12
# 12     4     8    12     4     5    91
# 13     4     8    12     2     6    10
# 14     4     8    12    34    72    11
# 15     4     8    12     4     8    12

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
df["Fare_INR"] = df["Fare"].apply(lambda x : x*80)

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    Fare_INR
# 0   580.000
# 1  5702.664
# 2   634.000
# 3  4248.000
# 4   644.000

# %%
df["nammeLength"] = df["Name"].apply(len)

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    Fare_INR  nammeLength
# 0   580.000           23
# 1  5702.664           51
# 2   634.000           22
# ...

# %%
def categoryFare(fare):
    if fare < 10:
        return "Cheap"
    elif fare < 20:
        return "Average"
    else:
        return "Expensive"

# %%
df['Fare_Category'] = df['Fare'].apply(categoryFare)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...
