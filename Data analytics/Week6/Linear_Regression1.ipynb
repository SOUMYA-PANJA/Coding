# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_excel('D:/Programming/Data analytics/static/Week 6/Important Data-20220714T173541Z-001/Important Data/reg2.xlsx')
data.columns
# Out:
# Index(['Hydrocarbon level', 'O2'], dtype='object')

# %%
x = data['Hydrocarbon level']
y = data['O2']

# %%
plt.figure()
sns.regplot(x=x, y=y, fit_reg=True)
plt.scatter(np.mean(x), np.mean(y), color = "red")
